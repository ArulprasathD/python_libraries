# %%
import pandas as pd

df= pd.read_csv('business_analysis_dataset.csv')

# %%
print(df)
# Out:
#      order_id  order_date region     category  quantity     sales      cost  \
# 0           1  2025-04-05  North  Electronics         2   1738.03   1036.32
# 1           2  2025-04-08  North    Furniture        10  21385.13  10915.59
# 2           3  2025-05-26  North    Furniture         9  21266.23  13976.66
# 3           4  2025-06-04  North         Food         7  17342.40   9614.94
# 4           5  2025-05-26  North         Food         2  18269.48  11334.10
# ..        ...         ...    ...          ...       ...       ...       ...
# 197       198  2025-11-14   East  Electronics        10  21749.57  13953.39
# 198       199  2025-10-15   East  Electronics         7   1532.40    940.39
# 199       200  2025-10-13  North         Food         7  42301.98  24753.46
# 200       201        1990  south         food         8  43157.34  30412.87
# 201       201        1990  south         food         8  43157.34  30412.87
#
#        profit
# 0      701.71
# 1    10469.54
# ...

# %%
df.head()
# Out:
#    order_id  order_date region     category  quantity     sales      cost  \
# 0         1  2025-04-05  North  Electronics         2   1738.03   1036.32
# 1         2  2025-04-08  North    Furniture        10  21385.13  10915.59
# 2         3  2025-05-26  North    Furniture         9  21266.23  13976.66
# 3         4  2025-06-04  North         Food         7  17342.40   9614.94
# 4         5  2025-05-26  North         Food         2  18269.48  11334.10
#
#      profit
# 0    701.71
# 1  10469.54
# 2   7289.57
# 3   7727.46
# 4   6935.38

# %%
df.tail()
# Out:
#      order_id  order_date region     category  quantity     sales      cost  \
# 197       198  2025-11-14   East  Electronics        10  21749.57  13953.39
# 198       199  2025-10-15   East  Electronics         7   1532.40    940.39
# 199       200  2025-10-13  North         Food         7  42301.98  24753.46
# 200       201        1990  south         food         8  43157.34  30412.87
# 201       201        1990  south         food         8  43157.34  30412.87
#
#        profit
# 197   7796.18
# 198    592.01
# 199  17548.52
# 200   6154.88
# 201   6154.88

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    202 non-null    int64
#  1   order_date  202 non-null    object
#  2   region      202 non-null    object
#  3   category    202 non-null    object
#  4   quantity    202 non-null    int64
#  5   sales       202 non-null    float64
#  6   cost        202 non-null    float64
#  7   profit      202 non-null    float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 12.8+ KB

# %%
df.describe()
# Out:
#          order_id    quantity         sales          cost        profit
# count  202.000000  202.000000    202.000000    202.000000    202.000000
# mean   101.495050    5.519802  25400.696733  17129.789703   8205.663564
# std     58.448025    2.984555  14840.608233  10417.621751   5725.422620
# min      1.000000    1.000000    675.510000    520.070000    155.440000
# 25%     51.250000    3.000000  11990.190000   7520.460000   3835.445000
# 50%    101.500000    6.000000  25268.260000  16652.570000   7266.975000
# 75%    151.750000    8.000000  40067.670000  25643.252500  12076.035000
# max    201.000000   10.000000  49968.990000  40298.080000  22519.420000

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'region', 'category', 'quantity', 'sales',
#        'cost', 'profit'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=202, step=1)

# %%
df['category'].head()
# Out:
# 0    Electronics
# 1      Furniture
# 2      Furniture
# 3           Food
# 4           Food
# Name: category, dtype: object

# %%
df[['category','quantity']]
# Out:
#         category  quantity
# 0    Electronics         2
# 1      Furniture        10
# 2      Furniture         9
# 3           Food         7
# 4           Food         2
# ..           ...       ...
# 197  Electronics        10
# 198  Electronics         7
# 199         Food         7
# 200         food         8
# 201         food         8
#
# [202 rows x 2 columns]

# %%
df.iloc[3]
# Out:
# order_id               4
# order_date    2025-06-04
# region             North
# category            Food
# quantity               7
# sales            17342.4
# cost             9614.94
# profit           7727.46
# Name: 3, dtype: object

# %%
df.loc[20]
# Out:
# order_id              21
# order_date    2025-01-20
# region              East
# category            Food
# quantity               9
# sales           47698.24
# cost            39248.59
# profit           8449.65
# Name: 20, dtype: object

# %%
df[df['quantity'] >= 9]
# Out:
#      order_id  order_date region     category  quantity     sales      cost  \
# 1           2  2025-04-08  North    Furniture        10  21385.13  10915.59
# 2           3  2025-05-26  North    Furniture         9  21266.23  13976.66
# 5           6  2025-02-18   East     Clothing         9   6678.90   5495.42
# 6           7  2025-11-08   East  Electronics        10  10018.29   5253.03
# 9          10  2025-07-09  South     Clothing         9  36591.78  20388.61
# 13         14  2025-07-19   West     Clothing         9  27179.38  20695.87
# 17         18  2025-06-04   East         Food         9  37668.45  28967.40
# 20         21  2025-01-20   East         Food         9  47698.24  39248.59
# 22         23  2025-08-27  North    Furniture        10  47374.00  25107.21
# 24         25  2025-12-10   West     Clothing         9  37885.63  28090.44
# 32         33  2025-05-15  South  Electronics         9  22706.37  14705.98
# ...

# %%
df[df['region'] == 'West'].head(10)
# Out:
#     order_id  order_date region     category  quantity     sales      cost  \
# 13        14  2025-07-19   West     Clothing         9  27179.38  20695.87
# 23        24  2025-03-09   West    Furniture         3  33157.67  27567.19
# 24        25  2025-12-10   West     Clothing         9  37885.63  28090.44
# 28        29  2025-10-19   West    Furniture         8  11104.72   6066.61
# 29        30  2025-02-22   West     Clothing         8  40471.10  22932.68
# 34        35  2025-04-28   West  Electronics         4   8732.40   5850.48
# 35        36  2025-05-26   West     Clothing         3  19259.17  16271.27
# 36        37  2025-09-22   West    Furniture         7  34981.28  26434.54
# 42        43  2025-02-01   West  Electronics         8  16150.77  12325.50
# 47        48  2025-01-03   West     Clothing         5  25517.75  15001.69
#
#       profit
# 13   6483.51
# 23   5590.48
# 24   9795.19
# 28   5038.11
# 29  17538.42
# 34   2881.92
# 35   2987.90
# 36   8546.74
# ...

# %%
df[(df['quantity'] >= 9) & (df['region'] == 'West')]
# Out:
#      order_id  order_date region   category  quantity     sales      cost  \
# 13         14  2025-07-19   West   Clothing         9  27179.38  20695.87
# 24         25  2025-12-10   West   Clothing         9  37885.63  28090.44
# 72         73  2025-07-27   West  Furniture        10  40842.82  33172.83
# 120       121  2025-08-17   West   Clothing        10   2491.47   1905.21
# 131       132  2025-02-09   West   Clothing        10  25657.92  20725.55
# 132       133  2025-12-10   West  Furniture         9  13725.05   6874.85
# 147       148  2025-12-09   West   Clothing        10  15308.14  12808.48
# 149       150  2025-01-27   West   Clothing        10  15145.68  11279.71
# 153       154  2025-05-11   West  Furniture        10  18560.63  10134.00
#
#       profit
# 13   6483.51
# 24   9795.19
# 72   7669.99
# 120   586.26
# 131  4932.37
# 132  6850.20
# 147  2499.66
# 149  3865.97
# 153  8426.63

# %%
df[df['region'].isin(['West','East'])]
# Out:
#      order_id  order_date region     category  quantity     sales      cost  \
# 5           6  2025-02-18   East     Clothing         9   6678.90   5495.42
# 6           7  2025-11-08   East  Electronics        10  10018.29   5253.03
# 7           8  2025-08-21   East    Furniture         4  43390.94  27468.38
# 10         11  2025-06-13   East  Electronics         1  11837.88   6051.94
# 13         14  2025-07-19   West     Clothing         9  27179.38  20695.87
# ..        ...         ...    ...          ...       ...       ...       ...
# 193       194  2025-01-07   East    Furniture         4  20065.54  14241.79
# 194       195  2025-02-01   West         Food         3  38325.96  23045.65
# 195       196  2025-04-17   East  Electronics         3   6894.69   4732.54
# 197       198  2025-11-14   East  Electronics        10  21749.57  13953.39
# 198       199  2025-10-15   East  Electronics         7   1532.40    940.39
#
#        profit
# 5     1183.48
# 6     4765.26
# ...

# %%
df[~df['region'].isin(['West','East'])]
# Out:
#      order_id  order_date region     category  quantity     sales      cost  \
# 0           1  2025-04-05  North  Electronics         2   1738.03   1036.32
# 1           2  2025-04-08  North    Furniture        10  21385.13  10915.59
# 2           3  2025-05-26  North    Furniture         9  21266.23  13976.66
# 3           4  2025-06-04  North         Food         7  17342.40   9614.94
# 4           5  2025-05-26  North         Food         2  18269.48  11334.10
# ..        ...         ...    ...          ...       ...       ...       ...
# 191       192  2025-05-07  North     Clothing         7  24540.25  16066.88
# 196       197  2025-01-15  North     Clothing         7  43157.34  22217.65
# 199       200  2025-10-13  North         Food         7  42301.98  24753.46
# 200       201        1990  south         food         8  43157.34  30412.87
# 201       201        1990  south         food         8  43157.34  30412.87
#
#        profit
# 0      701.71
# 1    10469.54
# ...

# %%
new_row = pd.DataFrame([{
    "order_id" : 201,
    "order_date" : 2025-11-24,
    "region" : "south",
    "category" : "food",
    "quantity" : 8,
    "sales" : 43157.34,
    "cost" : 30412.87,
    "profit" : 6154.88
}])

df = pd.concat([df,new_row],ignore_index = True)

df.to_csv("business_analysis_dataset.csv",index = False)

print(df.tail(1))
# Out:
#      order_id order_date region category  quantity     sales      cost  \
# 202       201       1990  south     food         8  43157.34  30412.87
#
#       profit
# 202  6154.88

# %%
df[df['quantity'] >= 9]
# Out:
#      order_id  order_date region     category  quantity     sales      cost  \
# 1           2  2025-04-08  North    Furniture        10  21385.13  10915.59
# 2           3  2025-05-26  North    Furniture         9  21266.23  13976.66
# 5           6  2025-02-18   East     Clothing         9   6678.90   5495.42
# 6           7  2025-11-08   East  Electronics        10  10018.29   5253.03
# 9          10  2025-07-09  South     Clothing         9  36591.78  20388.61
# 13         14  2025-07-19   West     Clothing         9  27179.38  20695.87
# 17         18  2025-06-04   East         Food         9  37668.45  28967.40
# 20         21  2025-01-20   East         Food         9  47698.24  39248.59
# 22         23  2025-08-27  North    Furniture        10  47374.00  25107.21
# 24         25  2025-12-10   West     Clothing         9  37885.63  28090.44
# 32         33  2025-05-15  South  Electronics         9  22706.37  14705.98
# ...

# %%
df.iloc[2]
# Out:
# order_id               3
# order_date    2025-05-26
# region             North
# category       Furniture
# quantity               9
# sales           21266.23
# cost            13976.66
# profit           7289.57
# Name: 2, dtype: object

# %%
df.head()
# Out:
#    order_id  order_date region     category  quantity     sales      cost  \
# 0         1  2025-04-05  North  Electronics         2   1738.03   1036.32
# 1         2  2025-04-08  North    Furniture        10  21385.13  10915.59
# 2         3  2025-05-26  North    Furniture         9  21266.23  13976.66
# 3         4  2025-06-04  North         Food         7  17342.40   9614.94
# 4         5  2025-05-26  North         Food         2  18269.48  11334.10
#
#      profit
# 0    701.71
# 1  10469.54
# 2   7289.57
# 3   7727.46
# 4   6935.38
