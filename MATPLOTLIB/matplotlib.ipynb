# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyterthemes
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,6])
ypoints = np.array([0,30])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoint = np.array([1,7])
ypoint = np.array([0,42])

plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint = np.array([1,6])
ypoint = np.array([3,30])

plt.plot(xpoint,ypoint,"o")
plt.show()

# %%
xpoint = np.array([1,2,3,4,5,6])
ypoint = np.array([3,12,6,15,30,21])

plt.plot(xpoint,ypoint)
plt.show()

# %%
ypoint = np.array([3,6,9,12,30])

plt.plot(ypoint)
plt.show()

# %%
ypoint = np.array([3,7,4,18,21])

plt.plot(ypoint)
plt.show()

# %%
ypoint = np.array([3,7,4,18,21])

plt.plot(ypoint,marker = "o")
plt.show()

# %%
ypoint = np.array([5,15,10,25,20])

plt.plot(ypoint,marker = "d")
plt.show()

# %%
xpoint = np.array([1,2,3,4,5,6])
ypoint = np.array([3,12,6,15,30,21])

plt.plot(xpoint,ypoint,linestyle = "dotted")
plt.show()

# %%
xpoint = np.array([1,2,3,4,5,6])
ypoint = np.array([3,12,6,15,30,21])

plt.plot(xpoint,ypoint,linestyle = "dashed")
plt.show()

# %%
xpoint = np.array([1,2,3,4,5,6])
ypoint = np.array([3,12,6,15,30,21])


plt.plot(xpoint,ypoint,ls = "-.")                #:,-.,-,--,or
plt.show()

# %%
xpoint = np.array([1,10])
ypoint = np.array([5,10])

plt.plot(xpoint,ypoint,color = 'r')
plt.show()

# %%
ypoint = np.array([1,7,3,11])

plt.plot(ypoint,c = '#4CAF50')

plt.show()

# %%
ypoint = np.array([1,7,3,11])

plt.plot(ypoint,c = 'hotpink')

plt.show()

# %%
ypoint = np.array([1,7,3,11])

plt.plot(ypoint,linewidth = 20.5)

plt.show()

# %%
y1 = np.array([1,7,3,11])
y2 = np.array([11,3,7,1])

plt.plot(y1,c = '#4CAF50')
plt.plot(y2,c = 'r')


plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.xlabel("rank")
plt.ylabel("score")
plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.xlabel("rank")
plt.ylabel("score")
plt.title("sport data")
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {"family" : "Serif","color" : "blue","size" : 20}
font2 = {"family" : "serif","color" : "r","size" : 25}


plt.plot(x,y)
plt.xlabel("Score",font1)
plt.ylabel("Rank",font1)
plt.title("Sports data",font2)

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {"family" : "Serif","color" : "blue","size" : 20}
font2 = {"family" : "serif","color" : "r","size" : 25}


plt.plot(x,y)
plt.xlabel("Score",font1)
plt.ylabel("Rank",font1)
plt.title("Sports data",font2)

plt.grid()

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {"family" : "Serif","color" : "blue","size" : 20}
font2 = {"family" : "serif","color" : "r","size" : 25}

plt.plot(x,y)
plt.xlabel("Score",font1)
plt.ylabel("Rank",font1)
plt.title("Sports data",font2)
plt.grid(axis = 'x')

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {"family" : "Serif","color" : "blue","size" : 20}
font2 = {"family" : "serif","color" : "r","size" : 25}

plt.plot(x,y)
plt.xlabel("Score",font1)
plt.ylabel("Rank",font1)
plt.title("Sports data",font2)
plt.grid(axis = 'y')

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {"family" : "Serif","color" : "blue","size" : 20}
font2 = {"family" : "serif","color" : "r","size" : 25}

plt.plot(x,y)
plt.xlabel("Score",font1)
plt.ylabel("Rank",font1)
plt.title("Sports data",font2)
plt.grid(color = 'r',linestyle = "--",linewidth = 0.6)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1point = np.array([1,6])
y1point = np.array([0,35])


plt.subplot(1,2,1)
plt.plot(x1point,y1point,marker = "d")

x1point = np.array([1,3,6,9,12])
y1point = np.array([1,15,8,25,18])

plt.subplot(1,2,2)
plt.plot(x1point,y1point,ls = "dashed")
plt.show()

# %%
xpoint = np.array([1,6])
ypoint = np.array([0,35])

plt.subplot(2,1,1)
plt.plot(xpoint,ypoint,ls = ":")

xpoint = np.array([1,3,6,9,12])
ypoint = np.array([1,15,8,25,18])


plt.subplot(2,1,2)
plt.plot(xpoint,ypoint,c = "hotpink")
plt.suptitle("analysis")
plt.show()

# %%
x = np.array([1,5])
y = np.array([5,30])

plt.subplot(3,3,1)
plt.plot(x,y,color = 'r')

x = np.array([1,5])
y = np.array([3,27])

plt.subplot(3,3,2)
plt.plot(x,y,color = 'r')

x = np.array([1,5])
y = np.array([5,30])

plt.subplot(3,3,3)
plt.plot(x,y,color = 'r')

x = np.array([1,5])
y = np.array([5,30])

plt.subplot(3,3,4)
plt.plot(x,y,color = 'r')

x = np.array([1,5])
y = np.array([5,30])

plt.subplot(3,3,5)
plt.plot(x,y,color = 'r')

x = np.array([1,5])
y = np.array([5,30])

plt.subplot(3,3,6)
plt.plot(x,y,color = 'r')

x = np.array([1,5])
y = np.array([5,30])

plt.subplot(3,3,7)
plt.plot(x,y,color = 'r')

x = np.array([1,5])
y = np.array([5,30])

plt.subplot(3,3,8)
plt.plot(x,y,color = 'r')

x = np.array([1,5])
y = np.array([5,30])

plt.subplot(3,3,9)
plt.plot(x,y,color = 'r')

plt.suptitle("MY SHOP")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoint = np.array([2,4,7,8,18,20,27,30,35,39,41,45,23,12,43,19])
ypoint = np.array([100,103,94,87,88,81,78,61,53,51,49,37,21,19,16,10])


plt.scatter(xpoint,ypoint)
plt.show()

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
plt.ylabel("speed")
plt.xlabel("age")

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y,c = "r")

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y,c = "b")

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x, y,c =colors,cmap = "viridis")

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,18])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,118])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x, y,c =colors,cmap='viridis')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["stock","salary","inventory","sales"])
y = np.array([3,8,6,11])
font = {"family" : "serif","size" : 20,"color" : "blue"}

plt.bar(x,y)
plt.title("Shop data",font)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["stock","salary","inventory","sales"])
y = np.array([3,8,6,11])
font = {"family" : "serif","size" : 20,"color" : "blue"}

plt.barh(x,y)
plt.title("Shop data",font)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Stock","Salary","Inventory","Sales"])
y = np.array([3,8,6,11])
font = {"family" : "serif","size" : 20,"color" : "#ff0066"}

plt.bar(x,y,color = "#000099")
plt.title("Shop data",font)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Stock","Salary","Inventory","Sales"])
y = np.array([3,8,6,11])
font = {"family" : "serif","size" : 20,"color" : "#ff0066"}

plt.bar(x,y,color = "#000099",width = 0.5)
plt.title("Shop data",font)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.4,color = "#33cc33")
plt.show()

# %%
x = np.random.normal(180,10,44)

plt.hist(x)
plt.show()

# %%
x = np.random.normal(170,10,100)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabel = (["apple","orange","pineapple","berry"])

plt.pie(y,labels = mylabel)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabel = (["apple","orange","pineapple","berry"])
myexplode = ([0.2,0,0,0])

plt.pie(y,labels = mylabel,explode = myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabel = (["apple","orange","pineapple","berry"])

plt.pie(y,labels = mylabel,startangle = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabel = (["apple","orange","pineapple","berry"])
myexplode = ([0.2,0,0,0])

plt.pie(y,labels = mylabel,explode = myexplode,shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabel = (["apple","orange","pineapple","berry"])
myexplode = ([0.2,0,0,0])
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y,labels = mylabel,explode = myexplode,shadow = True,colors = mycolors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabel = (["apple","orange","pineapple","berry"])
myexplode = ([0.2,0,0,0])
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y,labels = mylabel,explode = myexplode,shadow = True,colors = mycolors)
plt.legend(title = "fruits")
plt.show()
