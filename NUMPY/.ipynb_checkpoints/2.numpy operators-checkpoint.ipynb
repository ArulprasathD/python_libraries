# %% [markdown]
# # operators

# %%
import numpy as np

a = np.array([1,2,3])
b = np.array([10,20,30])

# %%
print(a + b)
# Out:
# [11 22 33]

# %% [markdown]
#               [1  ,  2  ,  3  ]
#
#                 |     |     |
#
#               [10  , 20  , 30]
#               -----------------
#               11    22     33

# %%
print(a-b)
# Out:
# [ -9 -18 -27]

# %%
print(a*b)
# Out:
# [10 40 90]

# %%
print(b/a)      #taking default float
# Out:
# [10. 10. 10.]

# %%
print(b // a)
# Out:
# [10 10 10]

# %% [markdown]
# #  different value

# %%
import numpy as np

a = np.array([1,2,3])
b = 5                   #--> numpy automatically created as [5 ,5 ,5] virutually (broadcasting)

# numpy is more effecient than list

# %%
print(a+b)
# Out:
# [6 7 8]

# %%
print(a-b)
# Out:
# [-4 -3 -2]

# %%
import numpy as np

a = np.array([1,2,3])                      #internally matching as a 2d ,without allocating memory
b = np.array([[10,20,30],[40,50,60]])

# %%
print(a+b)
# Out:
# [[11 22 33]
#  [41 52 63]]

# %%
print(a-b)
# Out:
# [[ -9 -18 -27]
#  [-39 -48 -57]]

# %%
import numpy as np
                                         #no of element mismatch
a = np.array([1,2])                      #incompatable
b = np.array([[10,20,30],[40,50,60]])

# %%
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 print(a+b)
#
# ValueError: operands could not be broadcast together with shapes (2,) (2,3)
